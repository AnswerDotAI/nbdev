# %% [markdown]
# ## Test `__file__` is set for exported notebooks

# %%
#| default_exp file_var

# %%
from pathlib import Path
p = Path(__file__)
assert p.name == 'file_var.py' and p.parent.name == 'nbdev'

# %%
__file__ = 'overridden'
assert __file__ == 'overridden'
