# %% [markdown]
# ## Test `__file__` is set for exported notebooks

# %%
#| default_exp file_var

# %%
from fastcore.test import test_eq
from pathlib import Path

# %%
p = Path(__file__)
test_eq(p.name, 'file_var.py')
test_eq(p.parent.name, 'nbdev')

# %%
__file__ = 'overridden'
test_eq(__file__, 'overridden')
